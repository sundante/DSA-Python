# %% [markdown]
# # Sources
#
# - <a href="https://youtu.be/T0u5nwSA0w0?si=OSEQP1wWNVnxydhW">Neetcode 150 Course - All Coding Interview Questions Solved</a>
# - <a href="https://leetcode.com/problem-list/plakya4j/">NeetCode 150</a>

# %% [markdown]
# ## 1.
